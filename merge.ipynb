# %%
import os
import mysql.connector
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
user_name = os.environ.get("root")
password =os.environ.get("Defne1469")

# %%
connection = mysql.connector.connect(host="127.0.0.1",
                                   user  = "root" ,
                                     passwd="",
                                   db="northwind",
                                     auth_plugin='mysql_native_password')

# %%
connection

# %%
tables=pd.read_sql_query("SHOW TABLES FROM northwind",connection)

# %%
tables["Tables_in_northwind"]
# Out:
# 0                       customers
# 1             employee_privileges
# 2                       employees
# 3     inventory_transaction_types
# 4          inventory_transactions
# 5                        invoices
# 6                   order_details
# 7            order_details_status
# 8                          orders
# 9                   orders_status
# 10              orders_tax_status
# 11                     privileges
# 12                       products
# 13         purchase_order_details
# 14          purchase_order_status
# 15                purchase_orders
# 16                  sales_reports
# 17                       shippers
# 18                        strings
# 19                      suppliers
# Name: Tables_in_northwind, dtype: object

# %%
customers = pd.read_sql_query(f"Select * from customers",connection)
employee_privileges = pd.read_sql_query(f"Select * from employee_privileges",connection)
employees = pd.read_sql_query(f"Select * from employees",connection)
inventory_transaction_types = pd.read_sql_query(f"Select * from inventory_transaction_types",connection)
inventory_transactions = pd.read_sql_query(f"Select * from inventory_transactions",connection)
invoices = pd.read_sql_query(f"Select * from invoices",connection)
order_details = pd.read_sql_query(f"Select * from order_details",connection)
order_details_status = pd.read_sql_query(f"Select * from order_details_status",connection)
orders = pd.read_sql_query(f"Select * from orders",connection)
orders_status = pd.read_sql_query(f"Select * from orders_status",connection)
orders_tax_status = pd.read_sql_query(f"Select * from orders_tax_status",connection)
privileges = pd.read_sql_query(f"Select * from privileges",connection)
products = pd.read_sql_query(f"Select * from products",connection)
purchase_order_details = pd.read_sql_query(f"Select * from purchase_order_details",connection)
purchase_order_status = pd.read_sql_query(f"Select * from purchase_order_status",connection)
purchase_orders = pd.read_sql_query(f"Select * from purchase_orders",connection)
sales_reports = pd.read_sql_query(f"Select * from sales_reports",connection)
shippers= pd.read_sql_query(f"Select * from shippers",connection)
strings = pd.read_sql_query(f"Select * from strings",connection)
suppliers = pd.read_sql_query(f"Select * from suppliers",connection)

# %%
customers
# Out:
#     id     company         last_name     first_name email_address  \
# 0    1   Company A            Bedecs           Anna          None
# 1    2   Company B  Gratacos Solsona        Antonio          None
# 2    3   Company C              Axen         Thomas          None
# 3    4   Company D               Lee      Christina          None
# 4    5   Company E         O’Donnell         Martin          None
# 5    6   Company F      Pérez-Olaeta      Francisco          None
# 6    7   Company G               Xie      Ming-Yang          None
# 7    8   Company H          Andersen      Elizabeth          None
# 8    9   Company I         Mortensen           Sven          None
# 9   10   Company J            Wacker         Roland          None
# 10  11   Company K           Krschne          Peter          None
# 11  12   Company L           Edwards           John          None
# 12  13   Company M            Ludick          Andre          None
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-beb83e6de722> in <module>
# ----> 1 output.name
#
# NameError: name 'output' is not defined

# %%
# Out:
# 'suppliers'
